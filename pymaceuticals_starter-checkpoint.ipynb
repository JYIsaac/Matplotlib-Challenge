# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merge_data_df = pd.merge(mouse_metadata, study_results, how="outer", on="Mouse ID")

# Display the data table for preview
merge_data_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
#Value counts returns 249 mice
merge_data_df["Mouse ID"].value_counts()
# Out:
# g989    13
# x822    10
# f545    10
# w422    10
# o331    10
#         ..
# x226     1
# t573     1
# x336     1
# b447     1
# d133     1
# Name: Mouse ID, Length: 249, dtype: int64

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
group_id = merge_data_df.groupby(['Mouse ID'])
duplicate_mice = group_id["Timepoint"].value_counts()
duplicate_df = duplicate_mice.to_frame()
duplicate_find_df = duplicate_df.loc[(duplicate_df["Timepoint"] >1)]

duplicate_find_df
# Out:
#                     Timepoint
# Mouse ID Timepoint
# g989     0                  2
#          5                  2
#          10                 2
#          15                 2
#          20                 2

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse = merge_data_df[merge_data_df['Mouse ID'] =="g989"]
duplicate_mouse
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
#Time points 0-20, Mouse ID g989 had two entries

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = merge_data_df[merge_data_df["Mouse ID"] !="g989"]
clean_df["Mouse ID"].value_counts()
# Out:
# x822    10
# t451    10
# j119    10
# w422    10
# o331    10
#         ..
# d133     1
# o848     1
# f932     1
# v199     1
# x226     1
# Name: Mouse ID, Length: 248, dtype: int64

# %%
# Checking the number of mice in the clean DataFrame.
#Mouse count by Mouse ID = 248

# %% [markdown]
# ## Summary Statistics

# %%
#Use describe method to retrieve,"Descriptive statistics include those that summarize the central tendency, 
#dispersion and shape of a dataset’s distribution, 
#excluding NaN values" (From pandas.pydata.org)
clean_df.describe()
# Out:
#         Age_months   Weight (g)    Timepoint  Tumor Volume (mm3)  \
# count  1880.000000  1880.000000  1880.000000         1880.000000
# mean     12.757979    25.660106    19.606383           50.435293
# std       7.181998     3.935064    14.094238            8.914197
# min       1.000000    15.000000     0.000000           22.050126
# 25%       7.000000    25.000000     5.000000           45.000000
# 50%      13.000000    27.000000    20.000000           48.933454
# 75%      19.250000    29.000000    30.000000           56.324075
# max      24.000000    30.000000    45.000000           78.567014
#
#        Metastatic Sites
# count       1880.000000
# mean           1.025000
# std            1.139971
# min            0.000000
# 25%            0.000000
# 50%            1.000000
# 75%            2.000000
# max            4.000000

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
#and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 

regimen_df = clean_df.groupby(["Drug Regimen"])
regimen_df.count().head(10)
# Out:
#               Mouse ID  Sex  Age_months  Weight (g)  Timepoint  \
# Drug Regimen
# Capomulin          230  230         230         230        230
# Ceftamin           178  178         178         178        178
# Infubinol          178  178         178         178        178
# Ketapril           188  188         188         188        188
# Naftisol           186  186         186         186        186
# Placebo            181  181         181         181        181
# Propriva           148  148         148         148        148
# Ramicane           228  228         228         228        228
# Stelasyn           181  181         181         181        181
# Zoniferol          182  182         182         182        182
#
#               Tumor Volume (mm3)  Metastatic Sites
# Drug Regimen
# Capomulin                    230               230
# Ceftamin                     178               178
# Infubinol                    178               178
# ...

# %%
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
#Create a dataframe for tumor volume to find mean, medican, variance, standard variation and SEM 
tumor_volume = regimen_df["Tumor Volume (mm3)"].describe()
tumor_volume
# Out:
#               count       mean       std        min        25%        50%  \
# Drug Regimen
# Capomulin     230.0  40.675741  4.994774  23.343598  37.685933  41.557809
# Ceftamin      178.0  52.591172  6.268188  45.000000  47.208427  51.776157
# Infubinol     178.0  52.884795  6.567243  36.321346  47.312353  51.820584
# Ketapril      188.0  55.235638  8.279709  45.000000  48.232987  53.698743
# Naftisol      186.0  54.331565  8.134708  45.000000  47.285874  52.509285
# Placebo       181.0  54.033581  7.821003  45.000000  47.459053  52.288934
# Propriva      148.0  52.320930  6.622085  45.000000  46.894328  50.446266
# Ramicane      228.0  40.216745  4.846308  22.050126  36.674635  40.673236
# Stelasyn      181.0  54.233149  7.710419  45.000000  48.047139  52.431737
# Zoniferol     182.0  53.236507  6.966589  45.000000  47.337876  51.818479
#
#                     75%        max
# Drug Regimen
# Capomulin     45.000000  48.158209
# Ceftamin      56.801438  68.923185
# ...

# %%
#drop columns we do not need (count, min, max and quartiles)
tumor_df = tumor_volume.drop(columns= ["count", "min", "25%", "50%", "75%", "max"])
tumor_df
# Out:
#                    mean       std
# Drug Regimen
# Capomulin     40.675741  4.994774
# Ceftamin      52.591172  6.268188
# Infubinol     52.884795  6.567243
# Ketapril      55.235638  8.279709
# Naftisol      54.331565  8.134708
# Placebo       54.033581  7.821003
# Propriva      52.320930  6.622085
# Ramicane      40.216745  4.846308
# Stelasyn      54.233149  7.710419
# Zoniferol     53.236507  6.966589

# %%
#Calculate median and add column to tumor dataframe
median = regimen_df["Tumor Volume (mm3)"].median()
tumor_df["Median"] = median

# %%
#Calculate variance
variance = regimen_df["Tumor Volume (mm3)"].var()
tumor_df["Variance"] = variance

# %%
sem = regimen_df["Tumor Volume (mm3)"].sem()
tumor_df["SEM"] = sem

# %%
# Assemble the resulting series into a single summary dataframe
tumor_df
# Out:
#                    mean       std     Median   Variance       SEM
# Drug Regimen
# Capomulin     40.675741  4.994774  41.557809  24.947764  0.329346
# Ceftamin      52.591172  6.268188  51.776157  39.290177  0.469821
# Infubinol     52.884795  6.567243  51.820584  43.128684  0.492236
# Ketapril      55.235638  8.279709  53.698743  68.553577  0.603860
# Naftisol      54.331565  8.134708  52.509285  66.173479  0.596466
# Placebo       54.033581  7.821003  52.288934  61.168083  0.581331
# Propriva      52.320930  6.622085  50.446266  43.852013  0.544332
# Ramicane      40.216745  4.846308  40.673236  23.486704  0.320955
# Stelasyn      54.233149  7.710419  52.431737  59.450562  0.573111
# Zoniferol     53.236507  6.966589  51.818479  48.533355  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
regimen_df.agg({'Tumor Volume (mm3)' :["mean", "std", "median", "sem", "var"]})
# Out:
#              Tumor Volume (mm3)
#                            mean       std     median       sem        var
# Drug Regimen
# Capomulin             40.675741  4.994774  41.557809  0.329346  24.947764
# Ceftamin              52.591172  6.268188  51.776157  0.469821  39.290177
# Infubinol             52.884795  6.567243  51.820584  0.492236  43.128684
# Ketapril              55.235638  8.279709  53.698743  0.603860  68.553577
# Naftisol              54.331565  8.134708  52.509285  0.596466  66.173479
# Placebo               54.033581  7.821003  52.288934  0.581331  61.168083
# Propriva              52.320930  6.622085  50.446266  0.544332  43.852013
# Ramicane              40.216745  4.846308  40.673236  0.320955  23.486704
# Stelasyn              54.233149  7.710419  52.431737  0.573111  59.450562
# Zoniferol             53.236507  6.966589  51.818479  0.516398  48.533355

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
#Set x-axis
x_axis = np.arange(len(regimen_df["Drug Regimen"]))
#Set y axis
mouse_tested = regimen_df["Mouse ID"].count()

mouse_tested_df = mouse_tested.to_frame()
y_axis = mouse_tested_df["Mouse ID"]


#timepoints_and_mice = timepoints_and_mice.set_index("Drug Regimen")

# %%
mouse_tested_df.plot(kind="bar")
plt.title("Mouse Tested per Drug")
plt.show()
plt.tight_layout()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.

unique = regimen_df["Mouse ID"].unique()

mice = []

for i in unique:
    mice.append(len(i))

plt.bar(x_axis, mice, color='b')
plt.xlabel("Drug Regimen")
plt.ylabel("Mice")
plt.title("Timepoints of Mice Tested per drug")
#Name ticks for x-axis
tick_label = [value for value in x_axis]
ticks = ["Capomulin", "Ceftamin", "Infubinol", "Ketapril", "Naftisol", "Placebo", "Propiva", "Ramicane", "Stelasyn", "Zoniferol"]
plt.xticks(tick_label, ticks, rotation=45)
# Out:
# ([<matplotlib.axis.XTick at 0x239db2c2130>,
# ...
#  [Text(0, 0, 'Capomulin'),
#   Text(1, 0, 'Ceftamin'),
#   Text(2, 0, 'Infubinol'),
#   Text(3, 0, 'Ketapril'),
#   Text(4, 0, 'Naftisol'),
#   Text(5, 0, 'Placebo'),
#   Text(6, 0, 'Propiva'),
#   Text(7, 0, 'Ramicane'),
#   Text(8, 0, 'Stelasyn'),
#   Text(9, 0, 'Zoniferol')])

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
gender = clean_df["Sex"].value_counts()
gender_df = gender.to_frame()

gender_pie = gender_df.plot(kind="pie", y='Sex', title=("Distribution of Female vs Male"))
plt.axis("equal")
# Out:
# (-1.1065502689644005,
#  1.1003119175697333,
#  -1.1079114197007642,
#  1.1041200173094385)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
labels=["Male", "Female"]
plt.pie(gender, labels=labels, autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x239db2a5fa0>,
# ...
#  [Text(-0.681404241901343, -0.8635324308437154, 'Male'),
#   Text(0.6814042419013431, 0.8635324308437154, 'Female')],
#  [Text(-0.3716750410370961, -0.47101768955111745, '51.0%'),
#   Text(0.3716750410370962, 0.47101768955111745, '49.0%')])

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
Capomulin_df = clean_df.loc[clean_df['Drug Regimen'] == "Capomulin"]
Ramicane_df = clean_df.loc[clean_df['Drug Regimen'] == "Ramicane"]
Infubinol_df = clean_df.loc[clean_df['Drug Regimen'] == "Infubinol"]
Ceftamin_df = clean_df.loc[clean_df['Drug Regimen'] == "Ceftamin"]

#Merge dataframes
combined_drug_df = [Capomulin_df, Ramicane_df, Infubinol_df, Ceftamin_df]
four_regimens = pd.concat(combined_drug_df)


# Start by getting the last (greatest) timepoint for each mouse
max_time = group_id["Timepoint"].max()


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
merge_data_df = pd.merge(four_regimens, max_time, on=["Mouse ID","Timepoint"])
# merge_data_df["MaxTime"] = merge_data_df["Timepoint_x"] == merge_data_df["Timepoint_y"]
merge_data_df.head()
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0     s185    Capomulin  Female           3          17         45
# 1     x401    Capomulin  Female          16          15         45
# 2     m601    Capomulin    Male          22          17         45
# 3     f966    Capomulin    Male          16          17         20
# 4     u364    Capomulin    Male          18          17         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           23.343598                 1
# 1           28.484033                 0
# 2           28.430964                 1
# 3           30.485985                 0
# 4           31.023923                 3

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol = []


# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for drug in treatments:
    volume = merge_data_df.loc[merge_data_df["Drug Regimen"]==drug]["Tumor Volume (mm3)"]
    tumor_vol.append(volume)
    #print(tumor_vol)

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    quartile = volume.quantile([0.25, 0.5, 0.75])
    lower = quartile[0.25]
    upper = quartile[0.75]
    iqr = upper - lower
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds
    lower_bound = lower - (1.5*iqr)
    upper_bound = upper + (1.5*iqr)
    outliers = volume.loc[(volume > upper_bound) | (volume < lower_bound)]
    if len(outliers) > 0:
        print(f"The outliers for {drug} are {outliers}")
# Out:
# The outliers for Infubinol are 55    36.321346
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
plt.boxplot(tumor_vol, labels=treatments)
plt.xlabel("Drug Regimen")
plt.ylabel("Tumor Volume")
plt.title("Tumor Volumes for Four Drug Regimen")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
Capomulin_df.head()
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# 13     s185    Capomulin  Female           3          17         15
# 14     s185    Capomulin  Female           3          17         20
#
#     Tumor Volume (mm3)  Metastatic Sites
# 10           45.000000                 0
# 11           43.878496                 0
# 12           37.614948                 0
# 13           38.177232                 0
# 14           36.866876                 0

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
Mouse185 = Capomulin_df.loc[Capomulin_df["Mouse ID"]=="s185"]

x_axis = Mouse185["Timepoint"]
y_axis = Mouse185["Tumor Volume (mm3)"]

plt.plot(x_axis,y_axis, color="blue", label="Mouse ID s185")
plt.title("Tumor Volume vs Time")
plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume (mm3)")
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
mouse_data = Capomulin_df.groupby("Mouse ID")

mouse_wt = mouse_data["Weight (g)"].mean()
mouse_tumor_vol = mouse_data["Tumor Volume (mm3)"].mean()

mouse_df = pd.DataFrame({
    "Weight (g)": mouse_wt,
    "Tumor Volume (mm3)": mouse_tumor_vol
})
mouse_df
# Out:
#           Weight (g)  Tumor Volume (mm3)
# Mouse ID
# b128              22           41.963636
# b742              21           40.083699
# f966              17           36.505973
# g288              19           41.990097
# g316              22           44.613344
# i557              24           44.805810
# i738              20           39.141053
# j119              23           44.465236
# j246              21           43.216925
# l509              21           44.434474
# l897              19           42.507261
# m601              17           34.847470
# m957              19           39.049816
# r157              25           45.798970
# r554              17           36.509212
# r944              25           43.367364
# s185              17           34.559143
# s710              23           42.803733
# t565              17           39.328725
# u364              17           39.887495
# v923              21           41.581595
# w150              23           41.384825
# ...

# %%
#Create x and y axis
x_scatter = mouse_df["Weight (g)"]
y_scatter = mouse_df["Tumor Volume (mm3)"]

plt.scatter(x_scatter, y_scatter, marker="o", s=x_scatter, alpha=0.75)
plt.title("Tumor Volume vs Weight")
plt.xlabel("Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

# %%
#Create x and y values
x_value = mouse_df["Weight (g)"]
y_value = mouse_df["Tumor Volume (mm3)"]

#Calculate the regression line y =mx + b
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_value, y_value)
regress_value = x_value * slope + intercept
line_r = "y =" +str(round(slope,2)) + "x + "+ str(round(intercept,2))

#Scatter plot
plt.scatter(x_value, y_value, marker="o", facecolors="blue", s=x_value, alpha=0.75)
plt.title("Tumor Volume vs Weight")
plt.xlabel("Weight (g)")
plt.ylabel("Tumor Volume (mm3)")

#Plot line
plt.plot(x_value, regress_value,"r-")
plt.annotate(line_r,(20,37), fontsize=12, color="red")

#Correlation coef
# Out:
# Text(20, 37, 'y =0.95x + 21.55')
